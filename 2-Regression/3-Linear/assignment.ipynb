# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %% [markdown]
# # Boston house prices dataset

# %%
bostonDataSet=datasets.load_boston()

# %%
boston = pd.DataFrame(data= np.c_[bostonDataSet['data'], bostonDataSet['target']],
                     columns= [*bostonDataSet['feature_names'], 'target'])

# %% [markdown]
# ## Dataset fields
# * CRIM per capita crime rate by town
# * ZN proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS proportion of non-retail business acres per town
# * CHAS Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# * NOX nitric oxides concentration (parts per 10 million)
# * RM average number of rooms per dwelling
# * AGE proportion of owner-occupied units built prior to 1940
# * DIS weighted distances to five Boston employment centres
# * RAD index of accessibility to radial highways
# * TAX full-value property-tax rate per $10,000
# * PTRATIO pupil-teacher ratio by town
# * B 1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
# * LSTAT % lower status of the population
# * MEDV Median value of owner-occupied homes in $1000’s

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
corr = boston.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a9e55_row0_col0, #T_a9e55_row1_col1, #T_a9e55_row2_col2, #T_a9e55_row3_col3, #T_a9e55_row4_col4, #T_a9e55_row5_col5, #T_a9e55_row6_col6, #T_a9e55_row7_col7, #T_a9e55_row8_col8, #T_a9e55_row9_col9, #T_a9e55_row10_col10, #T_a9e55_row11_col11, #T_a9e55_row12_col12, #T_a9e55_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a9e55_row0_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_a9e55_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_a9e55_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a9e55_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_a9e55_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a9e55_row0_col6, #T_a9e55_row1_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a9e55_row0_col7, #T_a9e55_row11_col4, #T_a9e55_row11_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# ...

# %%
X=boston.iloc[:,5:6].values
y=boston.iloc[:,-1:].values

# %% [markdown]
# # Linear regression model for Rooms - Price

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)

pred = lin_reg.predict(X_test)

accuracy_score = lin_reg.score(X_train,y_train)
print('Model Accuracy: ', accuracy_score)
# Out:
# Model Accuracy:  0.4970800097843844

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, pred, color='blue', linewidth=3)

plt.xlabel('Number of rooms')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# # Polynomial model for Room - Price

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## 2 polynomial features

# %%
pipeline = make_pipeline(PolynomialFeatures(2), LinearRegression())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline.fit(np.array(X_train), y_train)

y_pred=pipeline.predict(X_test)

df = pd.DataFrame({'x': X_test[:,0], 'y': y_pred[:,0]})
df.sort_values(by='x',inplace = True)
points = pd.DataFrame(df).to_numpy()

plt.plot(points[:, 0], points[:, 1],color="blue", linewidth=3)
plt.xlabel('Number of rooms')
plt.ylabel('Price')
plt.scatter(X,y, color="black")
plt.show()

# %%
accuracy_score = pipeline.score(X_train,y_train)
print('Model Accuracy: ', accuracy_score)
# Out:
# Model Accuracy:  0.556684522696484

# %% [markdown]
# ## 3 polynomial features

# %%
pipeline = make_pipeline(PolynomialFeatures(3), LinearRegression())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline.fit(np.array(X_train), y_train)

y_pred=pipeline.predict(X_test)

df = pd.DataFrame({'x': X_test[:,0], 'y': y_pred[:,0]})
df.sort_values(by='x',inplace = True)
points = pd.DataFrame(df).to_numpy()

plt.plot(points[:, 0], points[:, 1],color="blue", linewidth=3)
plt.xlabel('Number of rooms')
plt.ylabel('Price')
plt.scatter(X,y, color="black")
plt.show()

# %%
accuracy_score = pipeline.score(X_train,y_train)
print('Model Accuracy: ', accuracy_score)
# Out:
# Model Accuracy:  0.5725385423360618

# %% [markdown]
# ## 4 polynomial features

# %%
pipeline = make_pipeline(PolynomialFeatures(4), LinearRegression())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline.fit(np.array(X_train), y_train)

y_pred=pipeline.predict(X_test)

df = pd.DataFrame({'x': X_test[:,0], 'y': y_pred[:,0]})
df.sort_values(by='x',inplace = True)
points = pd.DataFrame(df).to_numpy()

plt.plot(points[:, 0], points[:, 1],color="blue", linewidth=3)
plt.xlabel('Number of rooms')
plt.ylabel('Price')
plt.scatter(X,y, color="black")
plt.show()

# %%
accuracy_score = pipeline.score(X_train,y_train)
print('Model Accuracy: ', accuracy_score)
# Out:
# Model Accuracy:  0.5911801109284439

# %% [markdown]
# # Conclusion
# I see that polynomial model for Rooms:Price is not really working better than linear, but more complex. And I expect it will produce worse results for new values comparing to linear model. I think linear regression better describes the nature of Rooms-Prize relationship.
